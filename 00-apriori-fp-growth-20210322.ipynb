# %%
import mlxtend
import numpy as np
import pandas as pd

# %%
data = np.array([
    ['우유', '기저귀', '쥬스'],
    ['양상추', '기저귀', '맥주'],
    ['우유', '양상추', '기저귀', '맥주'],
    ['양상추', '맥주']
])

# %%
data = np.array([
    ['우유', '기저귀', '쥬스'],
    ['양상추', '기저귀', '맥주'],
    ['우유', '양상추', '기저귀', '맥주'],
    ['양상추', '맥주']
])

# %% [markdown]
# ## Apriori 알고리즘

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
te_ary
# Out:
# array([[ True, False, False,  True,  True],
#        [ True,  True,  True, False, False],
#        [ True,  True,  True,  True, False],
#        [False,  True,  True, False, False]])

# %%
te.columns_ # 기록정보 저장
# Out:
# ['기저귀', '맥주', '양상추', '우유', '쥬스']

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      기저귀     맥주    양상추     우유     쥬스
# 0   True  False  False   True   True
# 1   True   True   True  False  False
# 2   True   True   True   True  False
# 3  False   True   True  False  False

# %%
# %%time
from mlxtend.frequent_patterns import apriori

apriori(df, min_support=0.5, use_colnames=True)
# Out:
# CPU times: user 12.6 ms, sys: 119 µs, total: 12.7 ms
# Wall time: 18.2 ms
#    support        itemsets
# 0     0.75           (기저귀)
# 1     0.75            (맥주)
# 2     0.75           (양상추)
# 3     0.50            (우유)
# 4     0.50       (기저귀, 맥주)
# 5     0.50      (양상추, 기저귀)
# 6     0.50       (우유, 기저귀)
# 7     0.75       (양상추, 맥주)
# 8     0.50  (양상추, 기저귀, 맥주)

# %% [markdown]
# ## FP-Growth 알고리즘

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      기저귀     맥주    양상추     우유     쥬스
# 0   True  False  False   True   True
# 1   True   True   True  False  False
# 2   True   True   True   True  False
# 3  False   True   True  False  False

# %%
# %%time
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.5, use_colnames=True)
# Out:
# CPU times: user 4.46 ms, sys: 0 ns, total: 4.46 ms
# Wall time: 5.08 ms
#    support        itemsets
# 0     0.75           (기저귀)
# 1     0.50            (우유)
# 2     0.75           (양상추)
# 3     0.75            (맥주)
# 4     0.50       (기저귀, 맥주)
# 5     0.50      (양상추, 기저귀)
# 6     0.50  (양상추, 기저귀, 맥주)
# 7     0.50       (우유, 기저귀)
# 8     0.75       (양상추, 맥주)

# %%
#import pandas as pd
#from mlxtend.preprocessing import TransactionEncoder
#추가분
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth, association_rules

association=fpgrowth(df, min_support=0.1, use_colnames=True)
association_rules(association, metric='confidence', min_threshold=0.5, support_only=False)
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0            (기저귀)            (맥주)                0.75                0.75
# 1             (맥주)           (기저귀)                0.75                0.75
# 2            (양상추)           (기저귀)                0.75                0.75
# 3            (기저귀)           (양상추)                0.75                0.75
# 4       (양상추, 기저귀)            (맥주)                0.50                0.75
# 5        (양상추, 맥주)           (기저귀)                0.75                0.75
# 6        (기저귀, 맥주)           (양상추)                0.50                0.75
# 7            (양상추)       (기저귀, 맥주)                0.75                0.50
# 8            (기저귀)       (양상추, 맥주)                0.75                0.75
# 9             (맥주)      (양상추, 기저귀)                0.75                0.50
# 10            (우유)           (기저귀)                0.50                0.75
# 11           (기저귀)            (우유)                0.75                0.50
# 12            (우유)            (맥주)                0.50                0.75
# 13            (우유)           (양상추)                0.50                0.75
# 14       (기저귀, 우유)            (맥주)                0.50                0.75
# 15        (우유, 맥주)           (기저귀)                0.25                0.75
# 16       (기저귀, 맥주)            (우유)                0.50                0.50
# 17            (우유)       (기저귀, 맥주)                0.50                0.50
# 18       (양상추, 우유)           (기저귀)                0.25                0.75
# 19       (기저귀, 우유)           (양상추)                0.50                0.75
# 20      (양상추, 기저귀)            (우유)                0.50                0.50
# 21            (우유)      (양상추, 기저귀)                0.50                0.50
# 22       (양상추, 우유)            (맥주)                0.25                0.75
# 23        (우유, 맥주)           (양상추)                0.25                0.75
# 24            (우유)       (양상추, 맥주)                0.50                0.75
# 25  (양상추, 기저귀, 우유)            (맥주)                0.25                0.75
# 26   (양상추, 우유, 맥주)           (기저귀)                0.25                0.75
# 27   (기저귀, 우유, 맥주)           (양상추)                0.25                0.75
# 28  (양상추, 기저귀, 맥주)            (우유)                0.50                0.50
# 29       (양상추, 우유)       (기저귀, 맥주)                0.25                0.50
# 30       (기저귀, 우유)       (양상추, 맥주)                0.50                0.75
# 31        (우유, 맥주)      (양상추, 기저귀)                0.25                0.50
# 32      (양상추, 기저귀)        (우유, 맥주)                0.50                0.25
# 33       (기저귀, 맥주)       (양상추, 우유)                0.50                0.25
# 34            (우유)  (양상추, 기저귀, 맥주)                0.50                0.50
# 35            (쥬스)            (우유)                0.25                0.50
# 36            (우유)            (쥬스)                0.50                0.25
# 37            (쥬스)           (기저귀)                0.25                0.75
# 38        (쥬스, 우유)           (기저귀)                0.25                0.75
# 39       (기저귀, 우유)            (쥬스)                0.50                0.25
# 40       (쥬스, 기저귀)            (우유)                0.25                0.50
# 41            (우유)       (쥬스, 기저귀)                0.50                0.25
# 42            (쥬스)       (기저귀, 우유)                0.25                0.50
# 43           (양상추)            (맥주)                0.75                0.75
# 44            (맥주)           (양상추)                0.75                0.75
#
#     support  confidence      lift  leverage  conviction
# 0      0.50    0.666667  0.888889   -0.0625        0.75
# 1      0.50    0.666667  0.888889   -0.0625        0.75
# 2      0.50    0.666667  0.888889   -0.0625        0.75
# 3      0.50    0.666667  0.888889   -0.0625        0.75
# 4      0.50    1.000000  1.333333    0.1250         inf
# 5      0.50    0.666667  0.888889   -0.0625        0.75
# 6      0.50    1.000000  1.333333    0.1250         inf
# 7      0.50    0.666667  1.333333    0.1250        1.50
# 8      0.50    0.666667  0.888889   -0.0625        0.75
# 9      0.50    0.666667  1.333333    0.1250        1.50
# 10     0.50    1.000000  1.333333    0.1250         inf
# 11     0.50    0.666667  1.333333    0.1250        1.50
# 12     0.25    0.500000  0.666667   -0.1250        0.50
# 13     0.25    0.500000  0.666667   -0.1250        0.50
# 14     0.25    0.500000  0.666667   -0.1250        0.50
# 15     0.25    1.000000  1.333333    0.0625         inf
# 16     0.25    0.500000  1.000000    0.0000        1.00
# 17     0.25    0.500000  1.000000    0.0000        1.00
# 18     0.25    1.000000  1.333333    0.0625         inf
# 19     0.25    0.500000  0.666667   -0.1250        0.50
# 20     0.25    0.500000  1.000000    0.0000        1.00
# 21     0.25    0.500000  1.000000    0.0000        1.00
# 22     0.25    1.000000  1.333333    0.0625         inf
# 23     0.25    1.000000  1.333333    0.0625         inf
# 24     0.25    0.500000  0.666667   -0.1250        0.50
# 25     0.25    1.000000  1.333333    0.0625         inf
# 26     0.25    1.000000  1.333333    0.0625         inf
# 27     0.25    1.000000  1.333333    0.0625         inf
# 28     0.25    0.500000  1.000000    0.0000        1.00
# 29     0.25    1.000000  2.000000    0.1250         inf
# 30     0.25    0.500000  0.666667   -0.1250        0.50
# 31     0.25    1.000000  2.000000    0.1250         inf
# 32     0.25    0.500000  2.000000    0.1250        1.50
# 33     0.25    0.500000  2.000000    0.1250        1.50
# 34     0.25    0.500000  1.000000    0.0000        1.00
# 35     0.25    1.000000  2.000000    0.1250         inf
# 36     0.25    0.500000  2.000000    0.1250        1.50
# 37     0.25    1.000000  1.333333    0.0625         inf
# 38     0.25    1.000000  1.333333    0.0625         inf
# 39     0.25    0.500000  2.000000    0.1250        1.50
# 40     0.25    1.000000  2.000000    0.1250         inf
# 41     0.25    0.500000  2.000000    0.1250        1.50
# 42     0.25    1.000000  2.000000    0.1250         inf
# 43     0.75    1.000000  1.333333    0.1875         inf
# 44     0.75    1.000000  1.333333    0.1875         inf
